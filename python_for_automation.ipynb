# %% [markdown]
# <a href="https://colab.research.google.com/github/ammarion/100-days-of-python/blob/master/python_for_automation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Using Python to Interact with the Operating System**

# %% [markdown]
# Let's do a rundown of some of the many things that we can do with Python to manipulate files and directories. We'll also look at specific file format called **`CSV`** that we'll use to read and write data. So we've got lots of good stuff ahead. Let's get to it.

# %% [markdown]
# ## Reading Files

# %% [markdown]
# When we open a file python checks to see if we have the required permissions to open the file and also create a **`File Descriptor`**
# A FD is a token, generated by the OS, that allows programs to do more operations with the file.

# %%
# Open an existing file
file = open("python.txt", "r")
# read and print the content of the file 
print(file.read())
print(file.readline())

# close the file 
file.close()
# Out:
# Python is an interpreted, high-level and general-purpose programming language.
# Python's design philosophy emphasizes code readability with its notable use of significant whitespace.

# %% [markdown]
# You maybe wondering, What is the difference between the readline() and read() methods?
#
# The readline() method reads a single line from the current position, the read() method reads from the current position until the end of the file.

# %%
# Other approch
with open("python.txt") as file:
  print(file.readline())
# Out:
# Python is an interpreted, high-level and general-purpose programming language.

# %% [markdown]
# The above approch ensures that files are closed automatically without you having to explicity do so.

# %% [markdown]
# # Iterating through Files

# %% [markdown]
# file objects can be iterated in the same way as other Python sequences like list or strings. This is really useful when you want to process a file line by line. Say for example you want to make a whole line uppercase before printing it. You can do that with something like this.

# %%
import os
def create_python_script(filename):
  comments = "# Start of a new Python program"
  with open(filename, "w") as file:
    file.write(comments)
  filesize = os.path.getsize(filename)
  return(filesize)

print(create_python_script("program.py"))
# Out:
# 31

# %% [markdown]
# # New Section

# %%
import os

def new_directory(directory, filename):
  # Before creating a new directory, check to see if it already exists
  if os.path.exists(directory) == False:
    os.mkdir(directory)

  # Create the new file inside of the new directory
  os.chdir(directory)
  with open (filename, "w") as file:
    pass

  # Return the list of files in the new directory
  return os.listdir()

print(new_directory("PythonPrograms", "script.py"))
# Out:
# ['script.py']

# %%
# Out:
# '/content/PythonPrograms'

# %%
import os
import datetime

def file_date(filename):
  # Create the file in the current directory
  with open(filename, 'w') as file:
    pass
  timestamp = os.path.getatime("newfile.txt")
  # Convert the timestamp into a readable format, then into a string
  time = datetime.datetime.fromtimestamp(timestamp)
  # Return just the date portion 
  # Hint: how many characters are in “yyyy-mm-dd”? 
  return ("{}".format(time.date()))

print(file_date("newfile.txt")) 
# Should be today's date in the format of yyyy-mm-dd
